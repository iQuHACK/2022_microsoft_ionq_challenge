# %%
import pandas as pd

# %%
df_aug = pd.read_excel('AUG_TICKETS.xlsx')
df_sep = pd.read_excel('SEP_TICKETS_3.xlsx')

# %%
comb_both = pd.concat([df_aug, df_sep])

# %%
#get date, - by day
#plot number of tickets on a certain date for a specific date
    #Customer Department, Customer Organization - location

# %%
t = df_aug["Submit Date Time"][0]
#t.month
df_aug['year'] = df_aug["Submit Date Time"].dt.year
df_aug['month'] = df_aug["Submit Date Time"].dt.month
df_aug['day'] = df_aug["Submit Date Time"].dt.day

# %%
df_aug.head()
# Out:
#          Country Incident/Work Order Regions New Zone  \
# 0  United States            Incident         NAM  NAM
# 1  United States            Incident         NAM  NAM
# 2  United States            Incident         NAM  NAM
# 3  United States            Incident         NAM  NAM
# 4  United States            Incident         NAM  NAM
#
#                                       Assigned Group  \
# 0  ATOS_WINTEL_VMWARE_CITRIX_NETWARE_ADMINISTRATI...
# 1                                       PALHRS_WW_L1
# 2                                       DPSFIN_WW_L1
# 3                                       DPSCUS_WW_L1
# 4                                       DPSCUS_WW_L1
#
#                            Assigned Org Associated RKM Associated RKM Number  \
# 0  Infrastructure Operations Management            NaN                   NaN
# 1               Application Maintenance            NaN                   NaN
# 2               Application Maintenance            NaN                   NaN
# ...

# %%
all_clean = comb_both[['Submit Date Time', 'Customer Department']].dropna()
aug_cl = df_aug[['Submit Date Time', 'Customer Department']].dropna()
sep_cl = df_sep[['Submit Date Time', 'Customer Department']].dropna()

# %%
all_clean['year'] = all_clean["Submit Date Time"].dt.year
all_clean['month'] = all_clean["Submit Date Time"].dt.month
all_clean['day'] = all_clean["Submit Date Time"].dt.day

aug_cl['year'] = aug_cl["Submit Date Time"].dt.year
aug_cl['month'] = aug_cl["Submit Date Time"].dt.month
aug_cl['day'] = aug_cl["Submit Date Time"].dt.day

#maybe try:, need some way to reorder the dates thooooo
#pd.to_datetime(df['birth_date']).dt.to_period('M')

# %%
sep_cl['year'] = sep_cl["Submit Date Time"].dt.year
sep_cl['month'] = sep_cl["Submit Date Time"].dt.month
sep_cl['day'] = sep_cl["Submit Date Time"].dt.day

# %%
#for each day, have # of events in xx department

myDict = {aug_cl["day"].iloc[0]: {aug_cl['Customer Department'].iloc[0]: 1}}

for index, row in aug_cl.iterrows():
    if row['day'] not in myDict:
        myDict[row['day']] = {}
    print('row date', row['day'])
    if row['Customer Department'] not in myDict[row['day']]:
        myDict[row['day']][row['Customer Department']] = 0
    myDict[row['day']][row['Customer Department']] = myDict[row['day']][row['Customer Department']] + 1
    
#need to order dates tho...
# Out:
# row date 4
# row date 7
# row date 4
# row date 27
# row date 28
# row date 3
# row date 18
# row date 3
# row date 13
# row date 24
# row date 4
# row date 6
# row date 31
# row date 20
# row date 27
# row date 31
# row date 21
# row date 17
# row date 14
# row date 27
# row date 31
# row date 27
# row date 12
# row date 26
# row date 20
# row date 26
# row date 18
# row date 28
# row date 19
# row date 20
# row date 19
# row date 10
# row date 28
# row date 3
# row date 18
# row date 10
# row date 3
# row date 3
# row date 3
# row date 31
# row date 26
# row date 7
# row date 25
# row date 24
# row date 26
# row date 24
# row date 17
# row date 31
# row date 20
# row date 21
# row date 31
# row date 26
# row date 26
# row date 3
# row date 24
# row date 17
# row date 20
# row date 16
# row date 28
# row date 12
# row date 31
# row date 19
# row date 4
# row date 18
# row date 26
# row date 26
# row date 31
# row date 5
# row date 19
# row date 25
# row date 18
# row date 24
# ...

# %%
myDict.keys()
# Out:
# dict_keys([4, 7, 27, 28, 3, 18, 13, 24, 6, 31, 20, 21, 17, 14, 12, 26, 19, 10, 25, 16, 5, 11, 8, 29, 30, 15, 23, 9, 22, 2, 1])

# %%
myDict.values()
# Out:
# dict_values([{'Sales': 557, 'Procurement': 132, 'Human Resources': 146, 'Supply Chain Planning': 155, 'Customer Projects & Services': 727, 'Industrial / Manufacturing': 402, 'General Management': 67, 'Customer Satisfaction &Quality': 407, 'Logistics': 299, 'Marketing': 316, 'Utilities / Facilities': 73, 'Technical': 493, 'Finance': 296, 'Undefined': 633, 'Digital Innovation & Technology': 916, 'Environment/Sustainable Development': 19, 'Information  Technology': 23}, {'Sales': 363, 'Customer Satisfaction &Quality': 238, 'Logistics': 175, 'Procurement': 98, 'Industrial / Manufacturing': 258, 'General Management': 51, 'Technical': 284, 'Digital Innovation & Technology': 673, 'Customer Projects & Services': 537, 'Human Resources': 93, 'Marketing': 225, 'Finance': 210, 'Undefined': 428, 'Supply Chain Planning': 111, 'Utilities / Facilities': 32, 'Environment/Sustainable Development': 20, 'Information  Technology': 13}, {'Customer Projects & Services': 818, 'Sales': 389, 'Procurement': 12
# ...

# %%
lists = sorted(myDict.items())

# %%
import matplotlib.pylab as plt

# %%
(x,y) = zip(*lists)
y[0]['Sales']
# Out:
# 13

# %%
plt.plot(x, y[:]['Sales'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-68-3b64258c7444> in <module>
# ----> 1 plt.plot(x, y[:]['Sales'])
#
# TypeError: tuple indices must be integers or slices, not str

# %%
values = myDict['Sales'].values()
values
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-71-b9a22a1220bc> in <module>
# ----> 1 values = myDict['Sales'].values()
#       2 values
#
# KeyError: 'Sales'

# %%
myDict = {aug_cl["Customer Department"].iloc[0]: {aug_cl['day'].iloc[0]: 1}}

for index, row in aug_cl.iterrows():
    if row['Customer Department'] not in myDict:
        myDict[row['Customer Department']] = {}
    if row['day'] not in myDict[row['Customer Department']]:
        myDict[row['Customer Department']][row['day']] = 0
    myDict[row['Customer Department']][row['day']] = myDict[row['Customer Department']][row['day']] + 1

# %%
lists
# Out:
# [(1, 13),
#  (2, 22),
#  (3, 476),
#  (4, 557),
#  (5, 470),
#  (6, 366),
#  (7, 363),
#  (8, 19),
#  (9, 23),
#  (10, 509),
#  (11, 439),
#  (12, 376),
#  (13, 389),
#  (14, 329),
#  (15, 15),
#  (16, 39),
#  (17, 441),
#  (18, 440),
#  (19, 386),
#  (20, 320),
#  (21, 342),
#  (22, 40),
#  (23, 28),
#  (24, 486),
#  (25, 449),
#  (26, 398),
#  (27, 389),
#  (28, 370),
#  (29, 30),
#  (30, 36),
#  (31, 514)]

# %%
x1, y1 = zip(*lists) # unpack a list of pairs into two tuples

lists = sorted(myDict['Sales'].items())
plt.plot(x1, y1)
plt.show()

# %%
y
# Out:
# ({'Customer Projects & Services': 49,
#   'Sales': 13,
#   'Procurement': 17,
#   'Digital Innovation & Technology': 40,
#   'Industrial / Manufacturing': 46,
#   'General Management': 5,
#   'Customer Satisfaction &Quality': 21,
#   'Logistics': 38,
#   'Marketing': 15,
#   'Technical': 147,
#   'Finance': 26,
#   'Human Resources': 9,
#   'Undefined': 40,
#   'Supply Chain Planning': 14,
#   'Environment/Sustainable Development': 1,
#   'Information  Technology': 14},
#  {'Logistics': 32,
#   'Customer Projects & Services': 50,
#   'Finance': 20,
#   'Utilities / Facilities': 2,
#   'Customer Satisfaction &Quality': 20,
#   'Marketing': 5,
#   'Supply Chain Planning': 20,
#   'Industrial / Manufacturing': 20,
#   'General Management': 10,
#   'Digital Innovation & Technology': 52,
#   'Sales': 22,
#   'Technical': 14,
#   'Undefined': 12,
#   'Human Resources': 6,
#   'Procurement': 8,
#   'Environment/Sustainable Development': 7,
#   'Information  Technology': 6},
# ...

# %%
lists = sorted(myDict['Customer Projects & Services'].items())
x1, y1 = zip(*lists) 
plt.plot(x1, y1)
plt.show()

# %%
lists = sorted(myDict['Sales'].items())
x1, y1 = zip(*lists)
plt.plot(x1, y1)
plt.show()

# %%
lists = sorted(myDict['Procurement'].items())
x1, y1 = zip(*lists) 
plt.plot(x1, y1)
plt.show()

# %%
lists = sorted(myDict['Digital Innovation & Technology'].items())
x1, y1 = zip(*lists)
plt.plot(x1, y1)
plt.show()

# %%
lists = sorted(myDict['Industrial / Manufacturing'].items())
x1, y1 = zip(*lists)
plt.plot(x1, y1)
plt.show()

# %%
lists = sorted(myDict['General Management'].items())
x1, y1 = zip(*lists)
plt.plot(x1, y1)
plt.show()

# %%
lists = sorted(myDict['Customer Satisfaction &Quality'].items())
x1, y1 = zip(*lists) 
plt.plot(x1, y1)
plt.show()

# %%
lists = sorted(myDict['Logistics'].items())
x1, y1 = zip(*lists) 
plt.plot(x1, y1)
plt.show()

# %%
lists = sorted(myDict['Marketing'].items())
x1, y1 = zip(*lists) 
plt.plot(x1, y1)
plt.show()

# %%
lists = sorted(myDict['Technical'].items())
x1, y1 = zip(*lists) 
plt.plot(x1, y1)
plt.show()

# %%
lists = sorted(myDict['Finance'].items())
x1, y1 = zip(*lists) 
plt.plot(x1, y1)
plt.show()

# %%
lists = sorted(myDict['Human Resources'].items())
x1, y1 = zip(*lists) 
plt.plot(x1, y1)
plt.show()

##increased on the 24th! (could be Local Admin Account removal or Cylance Optics Block Mode)

# %%
lists = sorted(myDict['Undefined'].items())
x1, y1 = zip(*lists) 
plt.plot(x1, y1)
plt.show()

# %%
lists = sorted(myDict['Supply Chain Planning'].items())
x1, y1 = zip(*lists)
plt.plot(x1, y1)
plt.show()

# %%
lists = sorted(myDict['Environment/Sustainable Development'].items())
x1, y1 = zip(*lists) 
plt.plot(x1, y1)
plt.show()

# %%
lists = sorted(myDict['Information  Technology'].items())
x1, y1 = zip(*lists) 
plt.plot(x1, y1)
plt.show()

#aug 19 - Sailpoint - Domain Change for passwords in email

# %%
#MS Teams App Store Governance	July 27th	August 30th
#Cylance Optics Block Mode	August 24th	August 24th 
#Local Admin Account removal	Aug 24th 	Aug 24th 
#Sailpoint - Domain Change for passwords in email	August 19th	August 19th
#Password Reset & Account Unlock Icon deployment	August	Sept 28th

# %%
myDict_sept = {sep_cl["Customer Department"].iloc[0]: {sep_cl['day'].iloc[0]: 1}}

for index, row in sep_cl.iterrows():
    if row['Customer Department'] not in myDict_sept:
        myDict_sept[row['Customer Department']] = {}
    if row['day'] not in myDict_sept[row['Customer Department']]:
        myDict_sept[row['Customer Department']][row['day']] = 0
    myDict_sept[row['Customer Department']][row['day']] = myDict_sept[row['Customer Department']][row['day']] + 1

# %%
sep_cl
# Out:
#           Submit Date Time              Customer Department  year  month  day
# 162    2020-09-24 15:51:57  Digital Innovation & Technology  2020      9   24
# 163    2020-09-21 13:14:32  Digital Innovation & Technology  2020      9   21
# 164    2020-09-18 20:17:25  Digital Innovation & Technology  2020      9   18
# 165    2020-09-28 20:37:34  Digital Innovation & Technology  2020      9   28
# 167    2020-09-08 16:33:54  Digital Innovation & Technology  2020      9    8
# ...                    ...                              ...   ...    ...  ...
# 110741 2020-09-30 00:26:06              Unknown SubFunction  2020      9   30
# 110742 2020-09-09 10:41:12              Unknown SubFunction  2020      9    9
# 110743 2020-09-01 14:46:24              Unknown SubFunction  2020      9    1
# 110744 2020-09-13 08:57:52     Customer Projects & Services  2020      9   13
# 110745 2020-09-16 21:16:21     Customer Projects & Services  2020      9   16
#
# [109475 rows x 5 columns]

# %%
lists = sorted(myDict_sept['Environment/Sustainable Development'].items())
x1, y1 = zip(*lists) 
plt.plot(x1, y1)
plt.show()

#spiked around 28th - could be Password Reset & Account Unlock Icon deployment

# %%
lists = sorted(myDict_sept['Information  Technology'].items())
x1, y1 = zip(*lists) 
plt.plot(x1, y1)
plt.show()

#really spiked around 28th! - could be Password Reset & Account Unlock Icon deployment

# %%
lists = sorted(myDict_sept['Logistics'].items())
x1, y1 = zip(*lists) 
plt.plot(x1, y1)
plt.show()
